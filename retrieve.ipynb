# %%
import pandas as pd

# %%
df = pd.read_csv("results/literature_review_results.csv")
df_filtered = df[(df["year"] >= 2023) & (df["citation_count"] > 10)]
print(df_filtered[["title", "year", "citation_count", "url"]].head(20).to_string(index=False))
# Out:
#                                                                                                                                    title   year  citation_count                                        url
#                                                                  Challenges in AI-driven Biomedical Multimodal Data Fusion and Analysis. 2025.0            15.0 https://europepmc.org/article/MED/40036568
#                                                                          Transformers and large language models in healthcare: A review. 2024.0            45.0 https://europepmc.org/article/MED/38878555
#                                           Multimodal Large Language Models in Health Care: Applications, Challenges, and Future Outlook. 2024.0            78.0 https://europepmc.org/article/MED/39321458
# Multimodal Mental Health Digital Biomarker Analysis From Remote Interviews Using Facial, Vocal, Linguistic, and Cardiovascular Patterns. 2024.0            12.0 https://europepmc.org/article/MED/38198249
#                                                   Multimodal data integration for oncology in the era of deep neural networks: a review. 2024.0            45.0 https://europepmc.org/article/MED/39118787
#                                                                            Decoding speech perception from non-invasive brain recordings 2023.0           170.0           https://openalex.org/W4387378260
#                                           A Comprehensive Review on Synergy of Multi-Modal Data and AI Technologies in Medical Diagnosis 2024.0           165.0           https://openalex.org/W4392168796
#                                                  Deep Learning for Time Series Classification and Extrinsic Regression: A Current Survey 2024.0           180.0           https://openalex.org/W4392199044
#                                      Foundations &amp; Trends in Multimodal Machine Learning: Principles, Challenges, and Open Questions 2024.0           131.0           https://openalex.org/W4394606408
#                                A review of deep learning-based information fusion techniques for multimodal medical image classification 2024.0           144.0           https://openalex.org/W4398202743
#                                                        Self-Supervised Contrastive Learning for Medical Time Series: A Systematic Review 2023.0            53.0           https://openalex.org/W4366829097
#                                                                                      Deep learning for time series forecasting: a survey 2025.0            79.0           https://openalex.org/W4407276595
#                                                                                 Machine Learning for Synthetic Data Generation: A Review 2023.0            80.0           https://openalex.org/W4319793437
#                                                Brain-Inspired Remote Sensing Foundation Models and Open Problems: A Comprehensive Survey 2023.0            34.0           https://openalex.org/W4386825235
#                                   SecV: LLM-based Secure Verilog Generation with Clue-Guided Exploration on Hardware-CWE Knowledge Graph 2024.0            31.0           https://openalex.org/W4401023459
#           How to e-mental health: a guideline for researchers and practitioners using digital technology in the context of mental health 2023.0            82.0           https://openalex.org/W4385639068
#                                                                    A perspective on human activity recognition from inertial motion data 2023.0            32.0           https://openalex.org/W4385428483
#                                                                                      Beyond Supervised Learning for Pervasive Healthcare 2023.0            30.0           https://openalex.org/W4384924487
#                                                                                                Graph Artificial Intelligence in Medicine 2024.0            26.0           https://openalex.org/W4396915095
#                                                                                                     Transformers in Healthcare: A Survey 2023.0            12.0           https://openalex.org/W4383175678
